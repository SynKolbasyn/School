# %% [markdown]
# <p style="align: center;"><img align=center src="https://s8.hostingkartinok.com/uploads/images/2018/08/308b49fcfbc619d629fe4604bceb67ac.jpg" style="height:450px;" width=500/></p>
#
# <h3 style="text-align: center;"><b>Школа глубокого обучения ФПМИ МФТИ</b></h3>
# <h3 style="text-align: center;"><b>Базовый поток. Осень 2020</b></h3>
#
# <h1 style="text-align: center;"><b>Неделя 1. Библиотека Pandas</b></h1>

# %% [markdown]
# Библиотека `pandas` активно используется в современном data science для работы с данными, которые могут быть представлены в виде таблиц (а это очень, очень большая часть данных)

# %% [markdown]
# `pandas` есть в пакете Anaconda, но если вдруг у Вас её по каким-то причинам нет, то можно установить, раскомментировав следующую команду:

# %%
#pip install pandas

# %%
import numpy as np
import pandas as pd #Стандартное сокращение для pandas. Всегда используйте его!

# %% [markdown]
# # pd.Series
#
# Тип данных pd.Series представляет собой одномерный набор данных. Отсутствующий данные записываются как `np.nan` (в этот день термометр сломался или метеоролог был пьян); они не участвуют в вычислении средних, среднеквадратичных отклонений и т.д.
#
# ### Создание
# Создадим Series из списка температур

# %%
some_list = [1, 3, 5, np.nan, 6, 8]
ser_1 = pd.Series(some_list)
ser_1
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
# Так же можно в явном виде указать индексы, чтобы потом было более удобно обращаться к элементам
ind = ['1st day', '2nd day', '3rd day', '4th day', '5rd day', '6th day']

ser_2 = pd.Series(some_list, index=ind)
ser_2
# Out:
# 1st day    1.0
# 2nd day    3.0
# 3rd day    5.0
# 4th day    NaN
# 5rd day    6.0
# 6th day    8.0
# dtype: float64

# %%
ser_2['4th day']
# Out:
# nan

# %%
# А еще можно дать pd.Series имя, чтобы было совсем красиво
ser_3 = pd.Series(some_list, index=ind, name='Temperature')
ser_3
# Out:
# 1st day    1.0
# 2nd day    3.0
# 3rd day    5.0
# 4th day    NaN
# 5rd day    6.0
# 6th day    8.0
# Name: Temperature, dtype: float64

# %% [markdown]
# ### Индексирование
# С индексами можно работать так же, как и в случае с обычным list.

# %%
print(ser_3[0])

print('-----------')

print(ser_3[1:3])

print('-----------')

print(ser_3[::-1])
# Out:
# 1.0
# -----------
# 2nd day    3.0
# 3rd day    5.0
# Name: Temperature, dtype: float64
# -----------
# 6th day    8.0
# 5rd day    6.0
# 4th day    NaN
# 3rd day    5.0
# 2nd day    3.0
# 1st day    1.0
# Name: Temperature, dtype: float64
# C:\Users\user\AppData\Local\Temp\ipykernel_19216\2409160489.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(ser_3[0])

# %% [markdown]
# ### Индексирование pd.Series по условиям

# %%
date_range = pd.date_range('20190101', periods=10)
ser_4 = pd.Series(np.random.rand(10), date_range)
ser_4
# Out:
# 2019-01-01    0.563074
# 2019-01-02    0.123251
# 2019-01-03    0.973318
# 2019-01-04    0.001950
# 2019-01-05    0.881574
# 2019-01-06    0.990725
# 2019-01-07    0.519609
# 2019-01-08    0.295538
# 2019-01-09    0.988411
# 2019-01-10    0.919471
# Freq: D, dtype: float64

# %%
ser_4 > 0.5
# Out:
# 2019-01-01     True
# 2019-01-02    False
# 2019-01-03     True
# 2019-01-04    False
# 2019-01-05     True
# 2019-01-06     True
# 2019-01-07     True
# 2019-01-08    False
# 2019-01-09     True
# 2019-01-10     True
# Freq: D, dtype: bool

# %% [markdown]
# В качестве индекса можно указать выражение, и нам будут возвращены только те элементы, для которых значение является `True`

# %%
ser_4[ser_4 > 0.5]
# Out:
# 2019-01-01    0.563074
# 2019-01-03    0.973318
# 2019-01-05    0.881574
# 2019-01-06    0.990725
# 2019-01-07    0.519609
# 2019-01-09    0.988411
# 2019-01-10    0.919471
# dtype: float64

# %%
ser_4[(ser_4 > 0.6) | (ser_4 < 0.2)]
# Out:
# 2019-01-02    0.123251
# 2019-01-03    0.973318
# 2019-01-04    0.001950
# 2019-01-05    0.881574
# 2019-01-06    0.990725
# 2019-01-09    0.988411
# 2019-01-10    0.919471
# dtype: float64

# %% [markdown]
# ### Сортировки
# Тип `pd.Series` можно отсортировать как по значениям, так и по индексу.

# %%
ser_4.sort_index()
# Out:
# 2019-01-01    0.563074
# 2019-01-02    0.123251
# 2019-01-03    0.973318
# 2019-01-04    0.001950
# 2019-01-05    0.881574
# 2019-01-06    0.990725
# 2019-01-07    0.519609
# 2019-01-08    0.295538
# 2019-01-09    0.988411
# 2019-01-10    0.919471
# Freq: D, dtype: float64

# %%
ser_4.sort_values()
# Out:
# 2019-01-04    0.001950
# 2019-01-02    0.123251
# 2019-01-08    0.295538
# 2019-01-07    0.519609
# 2019-01-01    0.563074
# 2019-01-05    0.881574
# 2019-01-10    0.919471
# 2019-01-03    0.973318
# 2019-01-09    0.988411
# 2019-01-06    0.990725
# dtype: float64

# %% [markdown]
# ### Операции с series
# Тип `pd.Series` можно модифицировать проще, чем стандартный ``list`` из Python.

# %%
ser_4 + 100
# Out:
# 2019-01-01    100.563074
# 2019-01-02    100.123251
# 2019-01-03    100.973318
# 2019-01-04    100.001950
# 2019-01-05    100.881574
# 2019-01-06    100.990725
# 2019-01-07    100.519609
# 2019-01-08    100.295538
# 2019-01-09    100.988411
# 2019-01-10    100.919471
# Freq: D, dtype: float64

# %%
np.exp(ser_4)
# Out:
# 2019-01-01    1.756062
# 2019-01-02    1.131168
# 2019-01-03    2.646712
# 2019-01-04    1.001952
# 2019-01-05    2.414697
# 2019-01-06    2.693187
# 2019-01-07    1.681369
# 2019-01-08    1.343849
# 2019-01-09    2.686962
# 2019-01-10    2.507964
# Freq: D, dtype: float64

# %%
term_1 = pd.Series(np.random.randint(0, 10, 5))
term_2 = pd.Series(np.random.randint(0, 10, 6))

term_1 + term_2
# Out:
# 0    11.0
# 1    15.0
# 2     7.0
# 3     5.0
# 4     3.0
# 5     NaN
# dtype: float64

# %%
term_1.shape
# Out:
# (5,)

# %% [markdown]
# # pd.DataFrame
#
# Тип данных pd.DataFrame представляет собой двумерную таблицу с данными. Имеет индекс и набор столбцов (возможно, имеющих разные типы). Таблицу можно построить, например, из словаря, значениями в котором являются одномерные наборы данных.
# ### Создание и основные объекты

# %%
# Dataframe можно составить из словаря. Ключ будет соответсовать колонке
some_dict = {'one': pd.Series([1,2,3], index=['a','b','c']),
             'two': pd.Series([1,2,3,4], index=['a','b','c','d']),
             'three': pd.Series([5,6,7,8], index=['a','b','c','d'])}
df = pd.DataFrame(some_dict)
df
# Out:
#    one  two  three
# a  1.0    1      5
# b  2.0    2      6
# c  3.0    3      7
# d  NaN    4      8

# %%
#Альтернативно, из списка списков с аргументом columns

some_array = [[1,1,5], [2,2,6], [3,3,7], [np.nan, 4,8]]
df = pd.DataFrame(some_array, index=['a', 'b', 'c', 'd'], columns=['one', 'two', 'three'])
df
# Out:
#    one  two  three
# a  1.0    1      5
# b  2.0    2      6
# c  3.0    3      7
# d  NaN    4      8

# %%
df.values
# Out:
# array([[10.,  1.,  5.,  5.],
#        [20.,  2.,  6.,  2.],
#        [30.,  3.,  7.,  1.],
#        [nan,  4.,  8.,  4.]])

# %%
df.columns
# Out:
# Index(['one', 'two', 'three'], dtype='object')

# %%
df.columns = ['first_column', 'second_column', 'third_column']
df.index = [1,2,3,4]
df
# Out:
#    first_column  second_column  third_column
# 1           1.0              1             5
# 2           2.0              2             6
# 3           3.0              3             7
# 4           NaN              4             8

# %% [markdown]
# ### Индексирование
# Есть очень много способов индексировать DataFrame в Pandas. Не все из них хорошие! Вот несколько удобных, но не универсальных.
#
# #### По колонкам
# Индексирование по колонке возращает pd.Series. Можно выбирать не одну колонку, а сразу несколько. Тогда снова вернётся pd.DataFrame.

# %%
first_column = df['first_column']
first_column
# Out:
# 1    1.0
# 2    2.0
# 3    3.0
# 4    NaN
# Name: first_column, dtype: float64

# %%
subset_dataframe = df[['first_column', 'second_column']]

subset_dataframe
# Out:
#    first_column  second_column
# 1           1.0              1
# 2           2.0              2
# 3           3.0              3
# 4           NaN              4

# %% [markdown]
# #### По строкам
# Можно писать любые слайлы, как в Python-списке. Они будут применяться к строкам. Нельзя обращаться по элементу!

# %%
df[1] #не сработает
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df[1] #не сработает
#
# File c:\Python311\Lib\site-packages\pandas\core\frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 1

# %%
df[:1]
# Out:
#    first_column  second_column  third_column
# 1           1.0              1             5

# %%
df[1:4]
# Out:
#    first_column  second_column  third_column
# 2           2.0              2             6
# 3           3.0              3             7
# 4           NaN              4             8

# %% [markdown]
# #### Универсальное индексирование: .loc и .iloc
#
# .loc и .iloc --- это два взаимозаменяемых атрибута, которые позволяют индексировать по обеим осям сразу. Путаницы не возникает из-за фиксированного порядка перечисления осей.

# %%
#По индексам: 
df.iloc[1:3, :2]
# Out:
#    first_column  second_column
# 2           2.0              2
# 3           3.0              3

# %%
df.loc[1:3, 'first_column':'third_column']
# Out:
#    first_column  second_column  third_column
# 1           1.0              1             5
# 2           2.0              2             6
# 3           3.0              3             7

# %% [markdown]
# Лучше использовать по умолчанию либо только loc, либо только .iloc! А лучше вообще всегда только .iloc, чтобы не запутаться.

# %% [markdown]
# ### Модификации датасета, создание новых колонок
# Можно просто брать и создавать новую колонку. Синтаксис тут вполне естественный.

# %%
new_column = [5,2,1,4]
df['new_column'] = new_column
df
# Out:
#    first_column  second_column  third_column  new_column
# 1          10.0              1             5           5
# 2          20.0              2             6           2
# 3          30.0              3             7           1
# 4           NaN              4             8           4

# %% [markdown]
# Аналогично, можно применять к отдельным колонкам арифметические операции (ведь колонки --- это Series!)

# %%
df['first_column'] = df['first_column'] * 10
df
# Out:
#    first_column  second_column  third_column  new_column
# 1          10.0              1             5           5
# 2          20.0              2             6           2
# 3          30.0              3             7           1
# 4           NaN              4             8           4

# %% [markdown]
# ## Реальный датасет
# Мы будем работать с датасетом ``Титаник``. Файлы необходимо скачать локально или загрузить с помощью функции ниже.
# ![alt text](https://drive.google.com/uc?id=1Tb52nFFsjI8sqv0AlMpx25aNJ62xzp5w)
#
# Информация о файлах:
#  - *titanic_data.csv* содержит различную информацию о пассажирах Титаника (билет, класс, возраст и т.п.)
#  - *titanic_surv.csv* содержит для каждого пассажира из первого файла информацию о том, выжил ли этот пассажир (метка 1) или нет (метка 0)
#
#
# ### Чтение из файла
# Обычно данные хранятся в виде таблиц в файлах формата .csv или .xlsx. На этом семинаре мы будем загружать данные из .csv файлов.
#
#
#
# Загрузим первый файл

# %%
# df_1 = pd.read_csv('titanic_data.csv')
# pass_link = 'https://www.dropbox.com/s/lyzcuxu1pdrw5qb/titanic_data.csv?dl=1'
# titanik_passengers = pd.read_csv(pass_link, ) #index_col=?
titanik_passengers = pd.read_csv("titanic_data.csv")

# %%
print('Всего пассажиров: ', len(titanik_passengers))
titanik_passengers.head()
# Out:
# Всего пассажиров:  891
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Разная информация о датасете
#
# Можно узнать размер таблицы, информацию о значениях таблицы, различные статистики по значениям.

# %%
titanik_passengers.values.shape
# Out:
# (891, 11)

# %%
titanik_passengers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Pclass       891 non-null    int64
#  2   Name         891 non-null    object
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
print('Максимальная цена за билет:', titanik_passengers['Fare'].max())
print('Медианная цена:', titanik_passengers['Fare'].median())
# Out:
# Максимальная цена за билет: 512.3292
# Медианная цена: 14.4542

# %%
titanik_passengers.groupby(['Pclass'])['Fare'].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
titanik_passengers['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
titanik_passengers.describe()
# Out:
# pandas.core.frame.DataFrame

# %%
titanik_passengers[titanik_passengers["Pclass"] == 3]
# Out:
#      PassengerId  Pclass                                      Name     Sex  \
# 0              1       3                   Braund, Mr. Owen Harris    male
# 2              3       3                    Heikkinen, Miss. Laina  female
# 4              5       3                  Allen, Mr. William Henry    male
# 5              6       3                          Moran, Mr. James    male
# 7              8       3            Palsson, Master. Gosta Leonard    male
# ..           ...     ...                                       ...     ...
# 882          883       3              Dahlberg, Miss. Gerda Ulrika  female
# 884          885       3                    Sutehall, Mr. Henry Jr    male
# 885          886       3      Rice, Mrs. William (Margaret Norton)  female
# 888          889       3  Johnston, Miss. Catherine Helen "Carrie"  female
# 890          891       3                       Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S
# 2    26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4    35.0      0      0            373450   8.0500   NaN        S
# 5     NaN      0      0            330877   8.4583   NaN        Q
# 7     2.0      3      1            349909  21.0750   NaN        S
# ..    ...    ...    ...               ...      ...   ...      ...
# 882  22.0      0      0              7552  10.5167   NaN        S
# 884  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  39.0      0      5            382652  29.1250   NaN        Q
# 888   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 890  32.0      0      0            370376   7.7500   NaN        Q
#
# [491 rows x 11 columns]

# %%
old_passengers = titanik_passengers[titanik_passengers["Age"] > 50]["Name"]
print(old_passengers)
print(old_passengers.sort_values())
# Out:
# 6                                McCarthy, Mr. Timothy J
# 11                              Bonnell, Miss. Elizabeth
# 15                      Hewlett, Mrs. (Mary D Kingcome)
# 33                                 Wheadon, Mr. Edward H
# 54                        Ostby, Mr. Engelhart Cornelius
#                              ...
# 820    Hays, Mrs. Charles Melville (Clara Jennings Gr...
# 829            Stone, Mrs. George Nelson (Martha Evelyn)
# 851                                  Svensson, Mr. Johan
# 857                               Daly, Mr. Peter Denis
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# Name: Name, Length: 64, dtype: object
# 275                Andrews, Miss. Kornelia Theodosia
# 571    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 493                          Artagaveytia, Mr. Ramon
# 630             Barkworth, Mr. Algernon Henry Wilson
# 150                       Bateman, Rev. Robert James
#                            ...
# 33                             Wheadon, Mr. Edward H
# 124                      White, Mr. Percival Wayland
# 406                 Widegren, Mr. Carl/Charles Peter
# 155                      Williams, Mr. Charles Duane
# 555                               Wright, Mr. George
# Name: Name, Length: 64, dtype: object

# %%
print(titanik_passengers[[name.startswith("A") for name in titanik_passengers["Name"]]]["PassengerId"])
# Out:
# 4        5
# 13      14
# 25      26
# 40      41
# 49      50
# 68      69
# 91      92
# 114    115
# 119    120
# 144    145
# 146    147
# 182    183
# 192    193
# 207    208
# 210    211
# 233    234
# 244    245
# 261    262
# 275    276
# 279    280
# 297    298
# 305    306
# 308    309
# 353    354
# 363    364
# 365    366
# 369    370
# 401    402
# 460    461
# 493    494
# 498    499
# 518    519
# 541    542
# 542    543
# 571    572
# 610    611
# 700    701
# 730    731
# 746    747
# 780    781
# 784    785
# 806    807
# 810    811
# 813    814
# 833    834
# 834    835
# 840    841
# 845    846
# 850    851
# 855    856
# 874    875
# Name: PassengerId, dtype: int64

# %%
print(titanik_passengers[[name.startswith("A") for name in titanik_passengers["Name"]]][["Name", "Age", "Ticket"]])
# Out:
#                                                   Name    Age  \
# 4                             Allen, Mr. William Henry  35.00
# 13                         Andersson, Mr. Anders Johan  39.00
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  38.00
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  40.00
# 49       Arnold-Franchi, Mrs. Josef (Josefine Franchi)  18.00
# 68                     Andersson, Miss. Erna Alexandra  17.00
# 91                          Andreasson, Mr. Paul Edvin  20.00
# 114                              Attalah, Miss. Malake  17.00
# 119                  Andersson, Miss. Ellis Anna Maria   2.00
# 144                         Andrew, Mr. Edgardo Samuel  18.00
# 146       Andersson, Mr. August Edvard ("Wennerstrom")  27.00
# 182              Asplund, Master. Clarence Gustaf Hugo   9.00
# 192    Andersen-Jensen, Miss. Carla Christine Nielsine  19.00
# 207                        Albimona, Mr. Nassef Cassem  26.00
# 210                                     Ali, Mr. Ahmed  24.00
# 233                     Asplund, Miss. Lillian Gertrud   5.00
# 244                               Attalah, Mr. Sleiman  30.00
# 261                  Asplund, Master. Edvin Rojj Felix   3.00
# 275                  Andrews, Miss. Kornelia Theodosia  63.00
# 279                   Abbott, Mrs. Stanton (Rosa Hunt)  35.00
# 297                       Allison, Miss. Helen Loraine   2.00
# 305                     Allison, Master. Hudson Trevor   0.92
# 308                                Abelson, Mr. Samuel  30.00
# 353                          Arnold-Franchi, Mr. Josef  25.00
# 363                                    Asim, Mr. Adola  35.00
# 365                     Adahl, Mr. Mauritz Nils Martin  30.00
# 369                      Aubart, Mme. Leontine Pauline  24.00
# 401                                    Adams, Mr. John  26.00
# 460                                Anderson, Mr. Harry  48.00
# 493                            Artagaveytia, Mr. Ramon  71.00
# 498    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.00
# 518  Angle, Mrs. William A (Florence "Mary" Agnes H...  36.00
# 541               Andersson, Miss. Ingeborg Constanzia   9.00
# 542                  Andersson, Miss. Sigrid Elisabeth  11.00
# 571      Appleton, Mrs. Edward Dale (Charlotte Lamson)  53.00
# 610  Andersson, Mrs. Anders Johan (Alfrida Konstant...  39.00
# 700  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  18.00
# 730                      Allen, Miss. Elisabeth Walton  29.00
# 746                        Abbott, Mr. Rossmore Edward  16.00
# 780                               Ayoub, Miss. Banoura  13.00
# 784                                   Ali, Mr. William  25.00
# 806                             Andrews, Mr. Thomas Jr  39.00
# 810                             Alexander, Mr. William  26.00
# 813                 Andersson, Miss. Ebba Iris Alfrida   6.00
# 833                             Augustsson, Mr. Albert  23.00
# 834                             Allum, Mr. Owen George  18.00
# 840                        Alhomaki, Mr. Ilmari Rudolf  20.00
# 845                                Abbing, Mr. Anthony  42.00
# 850            Andersson, Master. Sigvard Harald Elias   4.00
# 855                         Aks, Mrs. Sam (Leah Rosen)  18.00
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  28.00
#
#                  Ticket
# 4                373450
# 13               347082
# 25               347077
# 40                 7546
# 49               349237
# 68              3101281
# 91               347466
# 114                2627
# 119              347082
# 144              231945
# 146              350043
# 182              347077
# 192              350046
# 207                2699
# 210  SOTON/O.Q. 3101311
# 233              347077
# 244                2694
# 261              347077
# 275               13502
# 279           C.A. 2673
# 297              113781
# 305              113781
# 308           P/PP 3381
# 353              349237
# 363  SOTON/O.Q. 3101310
# 365              C 7076
# 369            PC 17477
# 401              341826
# 460               19952
# 493            PC 17609
# 498              113781
# 518              226875
# 541              347082
# 542              347082
# 571               11769
# 610              347082
# 700            PC 17757
# 730               24160
# 746           C.A. 2673
# 780                2687
# 784  SOTON/O.Q. 3101312
# 806              112050
# 810                3474
# 813              347082
# 833              347468
# 834                2223
# 840    SOTON/O2 3101287
# 845           C.A. 5547
# 850              347082
# 855              392091
# 874           P/PP 3381

# %% [markdown]
# ## Задание 1
# Опишите данный датасет: какое расределение женщин/мужчин в нем? Сколько пассажиров ехало в каждом классе? Какой средний/минимальный/максимальный возраст пассажиров?

# %%
print(len(titanik_passengers[titanik_passengers["Sex"] == "female"]) / len(titanik_passengers[titanik_passengers["Sex"] == "male"]))

print(titanik_passengers["Pclass"].value_counts())

print(titanik_passengers["Age"].mean())
print(titanik_passengers["Age"].min())
print(titanik_passengers["Age"].max())
# Out:
# 0.5441941074523396
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
# 29.69911764705882
# 0.42
# 80.0

# %% [markdown]
# ## Задание 2.
# Сгруппируйте записи по классам пассажиров, в каждой группе посчитайте средний возраст. Используйте метод ``pandas.DataFrame.groupby``.

# %%
print(titanik_passengers.groupby(['Pclass'])["Age"].mean())
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %% [markdown]
# ## Слияние таблиц
# Таблицы можно сливать несколькими способами. Мы рассмотрим слияние по индексу: метод называется ``pd.join``.

# %%
df_3 = pd.Series(np.random.rand(891),name="Randomnumbers")
df_4 = titanik_passengers.join(df_3)
df_4
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
#      Randomnumbers
# 0         0.378468
# 1         0.469816
# 2         0.258262
# 3         0.342627
# 4         0.403891
# ..             ...
# 886       0.640740
# 887       0.273238
# 888       0.178872
# 889       0.763986
# 890       0.184718
#
# [891 rows x 12 columns]

# %%
df_4["Randomnumbers"] > 0.5
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890    False
# Name: Randomnumbers, Length: 891, dtype: bool

# %%
df_4[df_4["Randomnumbers"] > 0.5]
# Out:
#      PassengerId  Pclass                                          Name  \
# 5              6       3                              Moran, Mr. James
# 7              8       3                Palsson, Master. Gosta Leonard
# 10            11       3               Sandstrom, Miss. Marguerite Rut
# 13            14       3                   Andersson, Mr. Anders Johan
# 15            16       2              Hewlett, Mrs. (Mary D Kingcome)
# ..           ...     ...                                           ...
# 880          881       2  Shelley, Mrs. William (Imanita Parrish Hall)
# 884          885       3                        Sutehall, Mr. Henry Jr
# 885          886       3          Rice, Mrs. William (Margaret Norton)
# 886          887       2                         Montvila, Rev. Juozas
# 889          890       1                         Behr, Mr. Karl Howell
#
#         Sex   Age  SibSp  Parch           Ticket     Fare Cabin Embarked  \
# 5      male   NaN      0      0           330877   8.4583   NaN        Q
# 7      male   2.0      3      1           349909  21.0750   NaN        S
# 10   female   4.0      1      1          PP 9549  16.7000    G6        S
# 13     male  39.0      1      5           347082  31.2750   NaN        S
# 15   female  55.0      0      0           248706  16.0000   NaN        S
# ..      ...   ...    ...    ...              ...      ...   ...      ...
# 880  female  25.0      0      1           230433  26.0000   NaN        S
# 884    male  25.0      0      0  SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5           382652  29.1250   NaN        Q
# 886    male  27.0      0      0           211536  13.0000   NaN        S
# 889    male  26.0      0      0           111369  30.0000  C148        C
#
#      Randomnumbers
# 5         0.858024
# 7         0.771409
# 10        0.672881
# 13        0.903249
# 15        0.546426
# ..             ...
# 880       0.584874
# 884       0.854534
# 885       0.605966
# 886       0.640740
# 889       0.763986
#
# [445 rows x 12 columns]

# %% [markdown]
# Теперь считаем данные по тому, кто выжил, а кто нет.

# %%
#df_2 = pd.read_csv('titanic_surv.csv')
# surv_link = 'https://www.dropbox.com/s/v35x9i6a1tc7emm/titanic_surv.csv?dl=1'
# df_2 = pd.read_csv(surv_link)
df_2 = pd.read_csv("titanic_surv.csv")

# %%
df_2
# Out:
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]

# %% [markdown]
# ### Задание 3.
# Слейте два датасета titanik_passengers и Survived.

# %%
titanik_passengers.join(df_2)
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 12 columns]

# %% [markdown]
# Построим матрицу корреляций пола, стоимости билета и класса. Для этого сначала отберём признаки.

# %%
df_for_corr = titanik_passengers[['Sex','Fare','Pclass']]

# %% [markdown]
# Проблема заключается в том, что Fare и Pclass - это числа, а Sex - это строка. Заменим все строки "male" на число 0, а строки "female" на число 1.

# %%
df_for_corr['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
df_for_corr['Sex'] == 'male'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
df_for_corr.loc[df_for_corr['Sex'] == 'male', 'Sex'] = 0
df_for_corr.loc[df_for_corr['Sex'] == 'female', 'Sex'] = 1

# %%
df_for_corr
# Out:
#     Sex     Fare  Pclass
# 0     0   7.2500       3
# 1     1  71.2833       1
# 2     1   7.9250       3
# 3     1  53.1000       1
# 4     0   8.0500       3
# ..   ..      ...     ...
# 886   0  13.0000       2
# 887   1  30.0000       1
# 888   1  23.4500       3
# 889   0  30.0000       1
# 890   0   7.7500       3
#
# [891 rows x 3 columns]

# %%
df_for_corr['Sex'] = df_for_corr['Sex'].astype('float')
df_for_corr['Pclass'] = df_for_corr['Pclass'].astype('float')
df_for_corr
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19216\1186214825.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_for_corr['Sex'] = df_for_corr['Sex'].astype('float')
# C:\Users\user\AppData\Local\Temp\ipykernel_19216\1186214825.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_for_corr['Pclass'] = df_for_corr['Pclass'].astype('float')
#      Sex     Fare  Pclass
# 0    0.0   7.2500     3.0
# 1    1.0  71.2833     1.0
# 2    1.0   7.9250     3.0
# 3    1.0  53.1000     1.0
# 4    0.0   8.0500     3.0
# ..   ...      ...     ...
# 886  0.0  13.0000     2.0
# 887  1.0  30.0000     1.0
# 888  1.0  23.4500     3.0
# 889  0.0  30.0000     1.0
# 890  0.0   7.7500     3.0
#
# [891 rows x 3 columns]

# %%
df_for_corr.corr()
# Out:
#              Sex      Fare  Pclass
# Sex     1.000000  0.182333 -0.1319
# Fare    0.182333  1.000000 -0.5495
# Pclass -0.131900 -0.549500  1.0000

# %% [markdown]
# ### Задание 4.
# а) Сколько всего выживших пассажиров?
# б) Сколько выживших пассажиров по каждому из возрастов (например, сколько выжило 21-летних, 22-летних, 23-летних, и т.д.)?
# в) Постройте матрицу корреляций факта выживания, пола, стоимости билета и возраста.
# г*) Постройте матрицу корреляций факта выживания, пола, стоимости билета, последней цифры номера билета и возраста.

# %%
len(df_2[df_2["Survived"] == 1])
# Out:
# 342

# %%
df_10 = titanik_passengers.join(df_2)
df_10[df_10["Survived"] == 1].groupby(["Age"]).count()["PassengerId"]
# Out:
# Age
# 0.42     1
# 0.67     1
# 0.75     2
# 0.83     2
# 0.92     1
#         ..
# 58.00    3
# 60.00    2
# 62.00    2
# 63.00    2
# 80.00    1
# Name: PassengerId, Length: 65, dtype: int64

# %%
df_11 = titanik_passengers.join(df_2)
df_11["Sex"] = df_11["Sex"] == "male"
df_11[["Survived", "Sex", "Fare", "Age"]].corr()
# Out:
#           Survived       Sex      Fare       Age
# Survived  1.000000 -0.543351  0.257307 -0.077221
# Sex      -0.543351  1.000000 -0.182333  0.093254
# Fare      0.257307 -0.182333  1.000000  0.096067
# Age      -0.077221  0.093254  0.096067  1.000000

# %%
df_12 = titanik_passengers.join(df_2)
df_12["Sex"] = df_12["Sex"] == "male"
for i, e in enumerate(df_12["Ticket"].values):
    try:
        df_12["Ticket"][i] = int(e[-1])
    except ValueError:
        df_12["Ticket"][i] = 0
df_12[["Survived", "Sex", "Ticket", "Fare", "Age"]].corr()
# Out:
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
# C:\Users\Mondegrin\AppData\Local\Temp\ipykernel_7232\4217324684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Ticket"][i] = int(e[-1])
#           Survived       Sex    Ticket      Fare       Age
# Survived  1.000000 -0.543351  0.015695  0.257307 -0.077221
# Sex      -0.543351  1.000000 -0.040775 -0.182333  0.093254
# Ticket    0.015695 -0.040775  1.000000 -0.043131 -0.058458
# Fare      0.257307 -0.182333 -0.043131  1.000000  0.096067
# Age      -0.077221  0.093254 -0.058458  0.096067  1.000000
